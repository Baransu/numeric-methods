# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
base = pd.read_csv("2_base.csv") 
balanced = pd.read_csv("2_balanced.csv") 
tylor = pd.read_csv("2_tylor.csv")

# %%
base.head(1000)
# Out:
#                 X  Wynik_przyblizony  Blad_wzgledny
# 0    1.000000e-30                0.0            1.0
# 1    1.023293e-30                0.0            1.0
# 2    1.047129e-30                0.0            1.0
# 3    1.071519e-30                0.0            1.0
# 4    1.096478e-30                0.0            1.0
# 5    1.122018e-30                0.0            1.0
# 6    1.148154e-30                0.0            1.0
# 7    1.174898e-30                0.0            1.0
# 8    1.202264e-30                0.0            1.0
# 9    1.230269e-30                0.0            1.0
# 10   1.258925e-30                0.0            1.0
# 11   1.288250e-30                0.0            1.0
# 12   1.318257e-30                0.0            1.0
# 13   1.348963e-30                0.0            1.0
# 14   1.380384e-30                0.0            1.0
# 15   1.412538e-30                0.0            1.0
# 16   1.445440e-30                0.0            1.0
# ...

# %%
plt.figure(figsize=(10,10))
plt.xlabel("X")
# plt.ylabel("Blad_wzgledny")
plt.plot(balanced["X"], balanced["Blad_wzgledny"], 'C1', label="Zbalansowana")
# plt.plot(base["X"], base["Blad_wzgledny"], 'C2', label="Funkcja wbudowana")
# plt.plot(tylor["X"], tylor["Blad_wzgledny"], 'C3', label="Szereg tylora")
plt.legend()
plt.xlim(0, 0.00000000000001)
plt.show()
